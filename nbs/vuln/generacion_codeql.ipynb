# %% [markdown]
# # Análisis de Seguridad con CodeQL

# %% [markdown]
# Este notebook ejecuta un análisis de seguridad estático sobre los repositorios clonados en `data/repos/` utilizando CodeQL, la herramienta de análisis de código de GitHub.
#
# ## ¿Qué es CodeQL?
#
# CodeQL es un motor de búsqueda de código que permite escribir consultas para encontrar vulnerabilidades, problemas de seguridad y defectos de codificación en el código fuente. Produce resultados en formato SARIF (Static Analysis Results Interchange Format).
#
# ## Flujo de Ejecución
#
# 1. **Descubrimiento de repositorios**: Escanea `data/repos/` para encontrar todos los subdirectorios
# 2. **Creación de base de datos CodeQL**: Para cada repositorio, CodeQL crea una base de datos indexada del código
# 3. **Análisis**: Se ejecutan consultas de seguridad predefinidas en la base de datos
# 4. **Generación de resultados**: Los hallazgos se convierten a formato JSON normalizado y se guardan en `data/results/`

# %% [markdown]
# ## Preparación: Importar `scripts/generate_codeql.py`
#
# A continuación importaremos el módulo `CodeQLAnalyzer` desde el archivo `scripts/generate_codeql.py`.

# %%
import sys
from pathlib import Path
import json
import pandas as pd

# Agregar el directorio scripts al path para importar el modulo generate_codeql
# Este módulo contiene la clase CodeQLAnalyzer que orquesta todo el análisis
project_root = next(
    p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'pyproject.toml').exists())
scripts_path = project_root / "scripts"
if str(scripts_path) not in sys.path:
    sys.path.insert(0, str(scripts_path))

print(f"Notebook working directory: {Path().cwd()}")
print(f"Project root: {project_root}")
print(f"Scripts path: {scripts_path}")
print(f"Importing from: generate_codeql.py")
# Out:
# Notebook working directory: /workspaces/produccion_software_emi305/nbs/vuln
# Project root: /workspaces/produccion_software_emi305
# Scripts path: /workspaces/produccion_software_emi305/scripts
# Importing from: generate_codeql.py

# %%
# Importar la clase CodeQLAnalyzer desde generate_codeql.py
from generate_codeql import CodeQLAnalyzer

print("✓ Importado correctamente: CodeQLAnalyzer desde scripts/generate_codeql.py")
# Out:
# ✓ Importado correctamente: CodeQLAnalyzer desde scripts/generate_codeql.py

# %% [markdown]
# ## Configuración

# %%
# Configurar rutas
repos_path = project_root / "data" / "repos"
output_path = project_root / "data" / "results"

# Crear analizador
analizador = CodeQLAnalyzer(
    repos_path=str(repos_path),
    output_path=str(output_path)
)

# Configurar para ejecución normal (no dry-run)
analizador.dry_run = False

print(f"Repos path: {repos_path}")
print(f"Output path: {output_path}")
print(f"Dry run: {analizador.dry_run}")
# Out:
# Repos path: /workspaces/produccion_software_emi305/data/repos
# Output path: /workspaces/produccion_software_emi305/data/results
# Dry run: False

# %% [markdown]
# ## Ejecución: Análisis CodeQL (usando `scripts/generate_codeql.py`)
#
# Ahora ejecutaremos el análisis CodeQL sobre todos los repositorios descubiertos. El script `generate_codeql.py` manejará automáticamente la orquestación completa.

# %%
# Descubrir repositorios usando el método del CodeQLAnalyzer
# Este método viene de scripts/generate_codeql.py
repositorios = analizador.discover_repositories()
print(f"Repositorios encontrados: {len(repositorios)}")
for repo in repositorios:
    print(f"  - {repo}")
# Out:
# Repositorios encontrados: 4
#   - data/repos/claude-code-action
#   - data/repos/genai-code-review
#   - data/repos/juice-shop
#   - data/repos/opencode

# %%
# | eval: false
print("Iniciando análisis CodeQL con scripts/generate_codeql.py...")
analizador.run()
print("✓ Análisis completado")
# Out:
# INFO | Usando CodeQL CLI: /usr/local/bin/codeql
# INFO | === Diagnóstico del Entorno CodeQL ===
# Iniciando análisis CodeQL con scripts/generate_codeql.py...
# INFO | ✓ CodeQL CLI: CodeQL command-line toolchain release 2.25.1.
# INFO | ✓ Node.js: v20.20.2
# INFO | ✓ npm: 10.8.2
# INFO | Verificando query packs...
# INFO | ✓ Query pack codeql/python-queries disponible
# INFO | ✓ Query pack codeql/javascript-queries disponible
# INFO | ✓ Query pack codeql/java-queries disponible
# INFO | === Fin Diagnóstico ===
#
# INFO | [1/4] Procesando repositorio data/repos/claude-code-action
# INFO | Lenguaje detectado en claude-code-action: javascript
# INFO | Directorio temporal CodeQL: /tmp/codeql_analysis
# INFO | Creando base de datos CodeQL para claude-code-action (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/codeql-suites/javascript-security-and-quality.qls
# WARNING | CodeQL devolvió un código de error:
#   Comando: /usr/local/bin/codeql database analyze /tmp/codeql_analysis/claude-code-action_db /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/codeql-suites/javascript-security-and-quality.qls --format=sarifv2.1.0 --output=/workspaces/produccion_software_emi305/data/results/claude-code-action_temp.sarif
#   Código de error: 99
#   STDERR: Running queries.
# Not caching stages during query-loading, since max heap size is only 1338 MB.
# [1/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/SemicolonInsertion.qlx.
# [2/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/InvalidPrototype.qlx.
# [3/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/ConditionalComments.qlx.
# [4/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/UnusedIndexVariable.qlx.
# [5/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/NonLinearPattern.qlx.
# [6/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/ForInComprehensionBlocks.qlx.
# [7/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/TemplateSyntaxInStringLiteral.qlx.
# [8/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/StrictModeCallStackIntrospection.qlx.
# [9/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/SyntaxError.qlx.
# [10/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/LengthComparisonOffByOne.qlx.
# [11/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/InconsistentNew.qlx.
# [12/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/IllegalInvocation.qlx.
# [13/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/ExpressionClosures.qlx.
# [14/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/BadTypeof.qlx.
# [15/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/YieldInNonGenerator.qlx.
# [16/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/ThisBeforeSuper.qlx.
# [17/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/DeleteVar.qlx.
# [18/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/SetterReturn.qlx.
# [19/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/PropertyWriteOnPrimitive.qlx.
# [20/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/SpuriousArguments.qlx.
# [21/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/WithStatement.qlx.
# [22/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Performance/ReDoS.qlx.
# [23/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Performance/PolynomialReDoS.qlx.
# [24/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Expressions/SuspiciousInvocation.qlx.
# [25/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Expressions/StringInsteadOfRegex.qlx.
# [26/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Expressions/SuspiciousPropAccess.qlx.
# [27/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Expressions/RedundantExpression.qlx.
# [28/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Expressions/DuplicateCondition.qlx.
# [29/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Expressions/ExprHasNoEffect.qlx.
# [30/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Expressions/UnclearOperatorPrecedence.qlx.
# [31/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Expressions/UnknownDirective.qlx.
# [32/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Expressions/ImplicitOperandConversion.qlx.
# [33/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Expressions/WhitespaceContradictsPrecedence.qlx.
# [34/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Expressions/DuplicateProperty.qlx.
# [35/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Expressions/UnboundEventHandlerReceiver.qlx.
# [36/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Expressions/MisspelledVariableName.qlx.
# [37/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Expressions/HeterogeneousComparison.qlx.
# [38/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Expressions/SelfAssignment.qlx.
# [39/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Expressions/DuplicateSwitchCase.qlx.
# [40/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Expressions/ComparisonWithNaN.qlx.
# [41/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Expressions/UnneededDefensiveProgramming.qlx.
# [42/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Expressions/ShiftOutOfRange.qlx.
# [43/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Expressions/MissingAwait.qlx.
# [44/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Expressions/MissingDotLengthInComparison.qlx.
# [45/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Expressions/MissingSpaceInAppend.qlx.
# [46/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/React
202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-918/ClientSideRequestForgery.qlx.
# [186/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-094/UnsafeCodeConstruction.qlx.
# [187/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-807/ConditionalBypass.qlx.
# [188/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-506/HardcodedDataInterpretedAsCode.qlx.
# [189/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-367/FileSystemRace.qlx.
# [190/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-384/SessionFixation.qlx.
# [191/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-078/IndirectCommandInjection.qlx.
# [192/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-377/InsecureTemporaryFile.qlx.
# [193/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-400/RemotePropertyInjection.qlx.
# [194/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-912/HttpToFileAccess.qlx.
# [195/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-200/FileAccessToHttp.qlx.
# [196/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-862/EmptyPasswordInConfigurationFile.qlx.
# [197/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-020/MissingRegExpAnchor.qlx.
# [198/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-020/MissingOriginCheck.qlx.
# [199/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Diagnostics/ExtractionErrors.qlx.
# [200/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Diagnostics/ExtractedFiles.qlx.
# [201/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Summary/LinesOfUserCode.qlx.
# [202/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Summary/LinesOfCode.qlx.
# Starting evaluation of codeql/javascript-queries/AngularJS/DependencyMismatch.ql.
# Starting evaluation of codeql/javascript-queries/AngularJS/DisablingSce.ql.
# [1/202 eval 5.4s] Evaluation done; writing results to codeql/javascript-queries/AngularJS/DependencyMismatch.bqrs.
# Starting evaluation of codeql/javascript-queries/AngularJS/DoubleCompilation.ql.
# [2/202 eval 28ms] Evaluation done; writing results to codeql/javascript-queries/AngularJS/DisablingSce.bqrs.
# Starting evaluation of codeql/javascript-queries/AngularJS/DuplicateDependency.ql.
# [3/202 eval 3ms] Evaluation done; writing results to codeql/javascript-queries/AngularJS/DoubleCompilation.bqrs.
# Starting evaluation of codeql/javascript-queries/AngularJS/IncompatibleService.ql.
# [4/202 eval 3ms] Evaluation done; writing results to codeql/javascript-queries/AngularJS/DuplicateDependency.bqrs.
# Starting evaluation of codeql/javascript-queries/AngularJS/InsecureUrlWhitelist.ql.
# [5/202 eval 2ms] Evaluation done; writing results to codeql/javascript-queries/AngularJS/IncompatibleService.bqrs.
# Starting evaluation of codeql/javascript-queries/AngularJS/MissingExplicitInjection.ql.
# [6/202 eval 3ms] Evaluation done; writing results to codeql/javascript-queries/AngularJS/InsecureUrlWhitelist.bqrs.
# Starting evaluation of codeql/javascript-queries/AngularJS/RepeatedInjection.ql.
# [7/202 eval 12ms] Evaluation done; writing results to codeql/javascript-queries/AngularJS/MissingExplicitInjection.bqrs.
# Starting evaluation of codeql/javascript-queries/AngularJS/UseNgSrc.ql.
# [8/202 eval 4ms] Evaluation done; writing results to codeql/javascript-queries/AngularJS/RepeatedInjection.bqrs.
# Starting evaluation of codeql/javascript-queries/DOM/DuplicateAttributes.ql.
# [9/202 eval 10.3s] Evaluation done; writing results to codeql/javascript-queries/AngularJS/UseNgSrc.bqrs.
# Starting evaluation of codeql/javascript-queries/DOM/MalformedIdAttribute.ql.
# [10/202 eval 14ms] Evaluation done; writing results to codeql/javascript-queries/DOM/DuplicateAttributes.bqrs.
# Starting evaluation of codeql/javascript-queries/DOM/PseudoEval.ql.
# [11/202 eval 16ms] Evaluation done; writing results to codeql/javascript-queries/DOM/MalformedIdAttribute.bqrs.
# Starting evaluation of codeql/javascript-queries/Declarations/ArgumentsRedefined.ql.
# [12/202 eval 652ms] Evaluation done; writing results to codeql/javascript-queries/DOM/PseudoEval.bqrs.
# Starting evaluation of codeql/javascript-queries/Declarations/AssignmentToConst.ql.
# [13/202 eval 15ms] Evaluation done; writing results to codeql/javascript-queries/Declarations/ArgumentsRedefined.bqrs.
# Starting evaluation of codeql/javascript-queries/Declarations/ClobberingVarInit.ql.
# [14/202 eval 14ms] Evaluation done; writing results to codeql/javascript-queries/Declarations/AssignmentToConst.bqrs.
# Starting evaluation of codeql/javascript-queries/Declarations/ConflictingFunctions.ql.
# [15/202 eval 9ms] Evaluation done; writing results to codeql/javascript-queries/Declarations/ClobberingVarInit.bqrs.
# Starting evaluation of codeql/javascript-queries/Declarations/DeadStoreOfLocal.ql.
# [16/202 eval 13ms] Evaluation done; writing results to codeql/javascript-queries/Declarations/ConflictingFunctions.bqrs.
# Starting evaluation of codeql/javascript-queries/Declarations/DeadStoreOfProperty.ql.
# [17/202 eval 664ms] Evaluation done; writing results to codeql/javascript-queries/Declarations/DeadStoreOfLocal.bqrs.
# Starting evaluation of codeql/javascript-queries/Declarations/DeclBeforeUse.ql.
# [18/202 eval 7.2s] Evaluation done; writing results to codeql/javascript-queries/Declarations/DeadStoreOfProperty.bqrs.
# Starting evaluation of codeql/javascript-queries/Declarations/DefaultArgumentReferencesNestedFunction.ql.
# [19/202 eval 15.5s] Evaluation done; writing results to codeql/javascript-queries/Declarations/DeclBeforeUse.bqrs.
# Starting evaluation of codeql/javascript-queries/Declarations/DuplicateVarDecl.ql.
# [20/202 eval 3ms] Evaluation done; writing results to codeql/javascript-queries/Declarations/DefaultArgumentReferencesNestedFunction.bqrs.
# Starting evaluation of codeql/javascript-queries/Declarations/IneffectiveParameterType.ql.
# [21/202 eval 1.1s] Evaluation done; writing results to codeql/javascript-queries/Declarations/DuplicateVarDecl.bqrs.
# Starting evaluation of codeql/javascript-queries/Declarations/MissingThisQualifier.ql.
# [22/202 eval 4.8s] Evaluation done; writing results to codeql/javascript-queries/Declarations/IneffectiveParameterType.bqrs.
# [23/202 eval 5.1s] Query failed: codeql/javascript-queries/Declarations/MissingThisQualifier.ql (Query evaluation ran out of Java heap (Java heap (and arrays) maximum: 802 MiB).
# (eventual cause: OutOfMemoryError "Java heap space")).
# CodeQL is out of memory. Try increasing the memory available to CodeQL using the --ram option.
#   Base de datos: /tmp/codeql_analysis/claude-code-action_db
#   Suite de queries: /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/codeql-suites/javascript-security-and-quality.qls
#   Archivo de salida esperado: /workspaces/produccion_software_emi305/data/results/claude-code-action_temp.sarif
#   Nota: Si el archivo SARIF existe, se intentará procesarlo igualmente
# WARNING | Archivo SARIF no fue generado para claude-code-action_db
# INFO | SARIF output length: 32 bytes
# WARNING | SARIF output muy pequeño (probablemente vacío): {"version": "2.1.0", "runs": []}
# INFO | parse_sarif: recibiendo 32 bytes
# INFO | parse_sarif: 0 runs encontrados
# INFO | parse_sarif: total_issues=0
# INFO | save_analysis: claude-code-action con 0 issues
# INFO | Analisis CodeQL guardado en data/results/claude-code-action-codeql.json
# INFO | [2/4] Procesando repositorio data/repos/genai-code-review
# INFO | Lenguaje detectado en genai-code-review: python
# INFO | Creando base de datos CodeQL para genai-code-review (lenguaje: python)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/python-queries/1.0.4/codeql-suites/python-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/produccion_software_emi305/data/results/genai-code-review_temp.sarif (128825 bytes)
# INFO | SARIF output length: 128825 bytes
# INFO | parse_sarif: recibiendo 128825 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 4 resultados en run[0]
# INFO | parse_sarif: total_issues=4
# INFO | save_analysis: genai-code-review con 4 issues
# INFO | Analisis CodeQL guardado en data/results/genai-code-review-codeql.json
# INFO | [3/4] Procesando repositorio data/repos/juice-shop
# INFO | Lenguaje detectado en juice-shop: javascript
# INFO | Creando base de datos CodeQL para juice-shop (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/codeql-suites/javascript-security-and-quality.qls
# WARNING | CodeQL devolvió un código de error:
#   Comando: /usr/local/bin/codeql database analyze /tmp/codeql_analysis/juice-shop_db /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/codeql-suites/javascript-security-and-quality.qls --format=sarifv2.1.0 --output=/workspaces/produccion_software_emi305/data/results/juice-shop_temp.sarif
#   Código de error: 99
#   STDERR: Running queries.
# Not caching stages during query-loading, since max heap size is only 1278 MB.
# [1/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/SemicolonInsertion.qlx.
# [2/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/InvalidPrototype.qlx.
# [3/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/ConditionalComments.qlx.
# [4/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/UnusedIndexVariable.qlx.
# [5/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/NonLinearPattern.qlx.
# [6/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures/ForInComprehensionBlocks.qlx.
# [7/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/LanguageFeatures
202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-078/UselessUseOfCat.qlx.
# [150/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-078/ShellCommandInjectionFromEnvironment.qlx.
# [151/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-078/UnsafeShellCommandConstruction.qlx.
# [152/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-078/CommandInjection.qlx.
# [153/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-078/SecondOrderCommandInjection.qlx.
# [154/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-178/CaseSensitiveMiddlewarePath.qlx.
# [155/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-614/ClearTextCookie.qlx.
# [156/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-502/UnsafeDeserialization.qlx.
# [157/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-916/InsufficientPasswordHash.qlx.
# [158/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-1004/ClientExposedCookie.qlx.
# [159/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-754/UnvalidatedDynamicMethodCall.qlx.
# [160/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-400/DeepObjectResourceExhaustion.qlx.
# [161/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-770/MissingRateLimiting.qlx.
# [162/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-770/ResourceExhaustion.qlx.
# [163/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-200/PrivateFileExposure.qlx.
# [164/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-830/FunctionalityFromUntrustedSource.qlx.
# [165/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-776/XmlBomb.qlx.
# [166/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-020/IncompleteHostnameRegExp.qlx.
# [167/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-020/OverlyLargeRange.qlx.
# [168/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-020/IncompleteUrlSchemeCheck.qlx.
# [169/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-020/IncorrectSuffixCheck.qlx.
# [170/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-020/IncompleteUrlSubstringSanitization.qlx.
# [171/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-020/UselessRegExpCharacterEscape.qlx.
# [172/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-116/IncompleteSanitization.qlx.
# [173/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-116/IncompleteMultiCharacterSanitization.qlx.
# [174/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-116/BadTagFilter.qlx.
# [175/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-116/IncompleteHtmlAttributeSanitization.qlx.
# [176/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-116/UnsafeHtmlExpansion.qlx.
# [177/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-116/DoubleEscaping.qlx.
# [178/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-611/Xxe.qlx.
# [179/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-843/TypeConfusionThroughParameterTampering.qlx.
# [180/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-834/LoopBoundInjection.qlx.
# [181/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-352/MissingCsrfMiddleware.qlx.
# [182/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-1275/SameSiteNoneCookie.qlx.
# [183/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-313/PasswordInConfigurationFile.qlx.
# [184/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-117/LogInjection.qlx.
# [185/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-918/ClientSideRequestForgery.qlx.
# [186/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-094/UnsafeCodeConstruction.qlx.
# [187/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-807/ConditionalBypass.qlx.
# [188/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-506/HardcodedDataInterpretedAsCode.qlx.
# [189/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-367/FileSystemRace.qlx.
# [190/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-384/SessionFixation.qlx.
# [191/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-078/IndirectCommandInjection.qlx.
# [192/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-377/InsecureTemporaryFile.qlx.
# [193/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-400/RemotePropertyInjection.qlx.
# [194/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-912/HttpToFileAccess.qlx.
# [195/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-200/FileAccessToHttp.qlx.
# [196/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-862/EmptyPasswordInConfigurationFile.qlx.
# [197/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-020/MissingRegExpAnchor.qlx.
# [198/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Security/CWE-020/MissingOriginCheck.qlx.
# [199/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Diagnostics/ExtractionErrors.qlx.
# [200/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Diagnostics/ExtractedFiles.qlx.
# [201/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Summary/LinesOfUserCode.qlx.
# [202/202] Loaded /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/Summary/LinesOfCode.qlx.
# Starting evaluation of codeql/javascript-queries/AngularJS/DependencyMismatch.ql.
# [1/202 eval 27.5s] Query failed: codeql/javascript-queries/AngularJS/DependencyMismatch.ql (Query evaluation ran out of Java heap (Java heap (and arrays) maximum: 766 MiB).
# (eventual cause: OutOfMemoryError "Java heap space")).
# CodeQL is out of memory. Try increasing the memory available to CodeQL using the --ram option.
#   Base de datos: /tmp/codeql_analysis/juice-shop_db
#   Suite de queries: /home/vscode/.codeql/packages/codeql/javascript-queries/1.0.3/codeql-suites/javascript-security-and-quality.qls
#   Archivo de salida esperado: /workspaces/produccion_software_emi305/data/results/juice-shop_temp.sarif
#   Nota: Si el archivo SARIF existe, se intentará procesarlo igualmente
# WARNING | Archivo SARIF no fue generado para juice-shop_db
# INFO | SARIF output length: 32 bytes
# WARNING | SARIF output muy pequeño (probablemente vacío): {"version": "2.1.0", "runs": []}
# INFO | parse_sarif: recibiendo 32 bytes
# INFO | parse_sarif: 0 runs encontrados
# INFO | parse_sarif: total_issues=0
# INFO | save_analysis: juice-shop con 0 issues
# INFO | Analisis CodeQL guardado en data/results/juice-shop-codeql.json
# INFO | [4/4] Procesando repositorio data/repos/opencode
# INFO | Lenguaje detectado en opencode: javascript
# INFO | Creando base de datos CodeQL para opencode (lenguaje: javascript)...

# %% [markdown]
# ## Inspección de Resultados

# %%
# | eval: false
# Listar archivos de resultados generados
output_path = project_root / "data" / "results"
codeql_files = sorted(output_path.glob("*-codeql.json"))

print(f"📁 Buscando en: {output_path}")
print(f"✓ Archivos de análisis CodeQL encontrados: {len(codeql_files)}")
for archivo in codeql_files:
    tamaño = archivo.stat().st_size / 1024  # KB
    print(f"  - {archivo.name} ({tamaño:.1f} KB)")

# %%
# | eval: false
# Cargar y mostrar resumen de UN análisis
results_dir = project_root / "data" / "results"
results_files = sorted(results_dir.glob("*-codeql.json"))

print(f"📂 Buscando en: {results_dir}")
print(f"📋 Archivos encontrados: {len(results_files)}")

if results_files:
    result_file = results_files[0]
    print(f"📖 Leyendo: {result_file.name}")

    with open(result_file, 'r', encoding='utf-8') as f:
        data_content = json.load(f)

    repo_name_clean = result_file.stem.replace('-codeql', '')
    total_found = data_content.get('total_issues', 0)

    print(f"\n📊 ANÁLISIS: {repo_name_clean}")
    print(f"{'='*50}")
    print(f"✓ Total de problemas encontrados: {total_found}")

    if total_found > 0:
        severity_data = data_content.get('issues_by_severity', {})
        print(f"\n🔍 Problemas por severidad:")
        for severity_type, count in severity_data.items():
            if count > 0:
                emoji = "🔴" if severity_type == "error" else "🟡" if severity_type == "warning" else "⚪"
                print(f"  {emoji} {severity_type}: {count}")
    else:
        print("⚠️  No se encontraron problemas")
else:
    print("❌ No se encontraron archivos de análisis CodeQL")

# %%
# | eval: false
# Mostrar problemas detallados
output_path_det = project_root / "data" / "results"
codeql_files_det = sorted(output_path_det.glob("*-codeql.json"))

if codeql_files_det:
    archivo_det = codeql_files_det[0]

    with open(archivo_det, 'r', encoding='utf-8') as f:
        analisis_det = json.load(f)

    issues_list = analisis_det.get('issues', [])

    print(f"📋 Leyendo: {archivo_det.name}")
    print(f"📊 Total de issues en archivo: {len(issues_list)}")

    if issues_list:
        # Crear DataFrame con los problemas
        df_issues = pd.DataFrame(issues_list)

        # Seleccionar y reordenar columnas
        cols_mostrar = ['rule_id', 'level', 'message', 'file']
        cols_disponibles = [c for c in cols_mostrar if c in df_issues.columns]
        df_mostrar = df_issues[cols_disponibles].head(20)

        print(f"\n📋 Primeros 20 problemas encontrados:")
        print(f"{'='*100}")
        for idx, row in df_mostrar.iterrows():
            print(f"\n{idx+1}. [{row['level'].upper()}] {row['rule_id']}")
            print(f"   📝 {row['message'][:80]}")
            if 'file' in row and pd.notna(row['file']):
                print(f"   📂 {row['file']}")

        if len(issues_list) > 20:
            print(f"\n... y {len(issues_list)-20} problemas más")
    else:
        print("⚠️  No hay detalles de problemas en el archivo")

# %% [markdown]
# ## Análisis Detallado de Problemas

# %%
# | eval: false
# Compilar estadísticas consolidadas
from collections import defaultdict

output_path_stats = project_root / "data" / "results"
codeql_files_stats = sorted(output_path_stats.glob("*-codeql.json"))

stats_consolidadas = {
    'total_repositories': len(codeql_files_stats),
    'total_issues': 0,
    'issues_by_repo': {},
    'issues_by_severity': defaultdict(int),
    'top_rules': defaultdict(int)
}

for archivo in codeql_files_stats:
    with open(archivo, 'r', encoding='utf-8') as f:
        data = json.load(f)

    repo_name = archivo.stem.replace('-codeql', '')
    total = data.get('total_issues', 0)

    stats_consolidadas['total_issues'] += total
    stats_consolidadas['issues_by_repo'][repo_name] = total

    # Contar por severidad
    for severity, count in data.get('issues_by_severity', {}).items():
        stats_consolidadas['issues_by_severity'][severity] += count

    # Contar top rules
    for issue in data.get('issues', []):
        rule = issue.get('rule_id', 'unknown')
        stats_consolidadas['top_rules'][rule] += 1

# Convertir defaultdicts a dicts para visualización
stats_consolidadas['issues_by_severity'] = dict(
    stats_consolidadas['issues_by_severity'])
stats_consolidadas['top_rules'] = dict(sorted(
    stats_consolidadas['top_rules'].items(),
    key=lambda x: x[1],
    reverse=True
)[:10])

print("\n📊 ESTADÍSTICAS CONSOLIDADAS DE CODEQL")
print(f"{'='*60}")
print(
    f"\n📁 Repositorios analizados: {stats_consolidadas['total_repositories']}")
print(f"🔴 Total de problemas: {stats_consolidadas['total_issues']}")

print(f"\n📋 Problemas por repositorio:")
for repo, count in stats_consolidadas['issues_by_repo'].items():
    print(f"  • {repo}: {count}")

print(f"\n⚠️  Problemas por severidad:")
for severity, count in sorted(stats_consolidadas['issues_by_severity'].items()):
    emoji = "🔴" if severity == "error" else "🟡" if severity == "warning" else "⚪"
    print(f"  {emoji} {severity}: {count}")

print(f"\n🎯 Top 10 reglas más comunes:")
for rule, count in list(stats_consolidadas['top_rules'].items())[:10]:
    print(f"  • {rule}: {count}")

# %% [markdown]
# ## Próximos Pasos
#
# Los resultados del análisis CodeQL se han guardado en `data/results/` con el patrón `{repo-name}-codeql.json`.
#
# ### Cómo usar estos resultados:
#
# 1. **Revisar vulnerabilidades críticas**: Filtrar por `level: "error"` para identificar problemas de seguridad críticos
# 2. **Seguimiento**: Integrar con sistemas de seguimiento de mermas (issues, PRs) para gestionar remediación
# 3. **Análisis de tendencias**: Comparar resultados entre repositorios y períodos de tiempo
# 4. **Automatizar**: Integrar estos análisis en CI/CD para detectar problemas continuamente
#
# #### Para agregar nuevos repositorios:
#
# 1. **Edita `data/repos.json`** y agrega nuevos repositorios:
#
# ```json
# {
#     "repositories": [
#         {
#             "url": "https://github.com/owner/repo-name.git",
#             "path": "data/repos/repo-name",
#             "ref": "v1.0.0"
#         }
#     ]
# }
# ```
#
# 2. **Ejecuta en la terminal** (esto clonará los repositorios y los agregará como submódulos):
#
# ```bash
# uv run python scripts/add_submodules.py
# ```
#
# 3. **Ejecuta el análisis** nuevamente desde el notebook o la terminal:
#
# ```bash
# uv run scripts/generate_codeql.py
# ```
